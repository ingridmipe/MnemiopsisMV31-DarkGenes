# %% [markdown]
# ## Modify `fantasia` output
# - **Input**: `results.csv` (output file from fantasia)
# - **Action**: Add two columns (Gene_ID and GOterm_depth)

# %%
# Import necessary libraries
import os
import sys
import re
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from itertools import combinations
import plotly.express as px
import plotly.graph_objects as go
from upsetplot import from_indicators, UpSet
from Bio import SeqIO
# Opcional / útil para estilos de plot
sns.set(style="whitegrid", context="notebook")

# Para mostrar los plots dentro del notebook
# %matplotlib inline

# %%
# Define paths and read input files
proteome_info_path = '/Users/ingridmipe/Documents/UM/Browne_Lab/data/GenProteomes/Mle_2023_oneseq_proteome.csv'
proteome_fasta_path = '/Users/ingridmipe/Documents/UM/Browne_Lab/data/GenProteomes/Mle_2023_oneseq_proteome.fasta'

proteome_info = pd.read_csv(proteome_info_path)
proteome_sequences = list(SeqIO.parse(proteome_fasta_path, "fasta"))

proteome_info
# Out:
#        Gene_ID  Num_Transcripts  \
# 0      g_16414                1
# 1        g_666                1
# 2        g_667                1
# 3      g_16419                1
# 4        g_668                2
# ...        ...              ...
# 15540  g_11239                2
# 15541  g_11240                3
# 15542  g_11241                1
# 15543  g_16809                1
# 15544  g_11242                1
#
#                                          Transcripts_IDs  Transcript_Lengths  \
# 0                                       ['anno2.3794_t']               [169]
# 1                                      ['anno1.g689.t1']               [208]
# 2                                      ['anno1.g690.t1']               [255]
# 3                                       ['anno2.3801_t']               [193]
# 4                  ['anno1.g691.t1', 'anno2.MSTRG.14.2']          [715, 654]
# ...                                                  ...                 ...
# 15540             ['anno1.g11650.t1', 'anno1.g11650.t2']          [149, 134]
# 15541  ['anno1.g11651.t1', 'anno1.g11651.t2', 'anno2....  [2514, 2516, 2556]
# 15542                                ['anno1.g11652.t1']               [402]
# 15543                                   ['anno2.6432_t']               [144]
# 15544                                ['anno1.g11653.t1']               [545]
#
#        Difference_Length   Longest_Transcript  Length
# 0                      0         anno2.3794_t     169
# 1                      0        anno1.g689.t1     208
# 2                      0        anno1.g690.t1     255
# 3                      0         anno2.3801_t     193
# 4                     61        anno1.g691.t1     715
# ...                  ...                  ...     ...
# 15540                 15      anno1.g11650.t1     149
# 15541                 42  anno2.MSTRG.20491.3    2556
# 15542                  0      anno1.g11652.t1     402
# 15543                  0         anno2.6432_t     144
# 15544                  0      anno1.g11653.t1     545
#
# [15545 rows x 7 columns]

# %%
# Define paths and read input files from corresponding fantasia experiment
fantasia_results_path = '/Users/ingridmipe/Documents/UM/Browne_Lab/results/fantasia/experiments/AllCells_20251030164736_MarkerGenes/results.csv'
fantasia_results = pd.read_csv(fantasia_results_path)

fantasia_results
# Out:
#                  accession       go_id category evidence_code  \
# 0             anno1.g10.t1  GO:0000122        P           IGI
# 1             anno1.g10.t1  GO:0000242        C           IDA
# 2             anno1.g10.t1  GO:0001725        C           IDA
# 3             anno1.g10.t1  GO:0005768        C           IDA
# 4             anno1.g10.t1  GO:0005783        C           IDA
# ...                    ...         ...      ...           ...
# 167876  anno2.MSTRG.9998.2  GO:0060298        P           IMP
# 167877  anno2.MSTRG.9998.2  GO:0070252        P           IMP
# 167878  anno2.MSTRG.9998.2  GO:0071670        P           IMP
# 167879  anno2.MSTRG.9998.2  GO:0071963        P           IMP
# 167880  anno2.MSTRG.9998.2  GO:1904888        P           IMP
#
#                                            go_description  distance  \
# 0       negative regulation of transcription by RNA po...    0.0119
# 1                                 pericentriolar material    0.0410
# 2                                            stress fiber    0.0300
# 3                                                endosome    0.0425
# 4                                   endoplasmic reticulum    0.0425
# ...                                                   ...       ...
# 167876      positive regulation of sarcomere organization    0.1139
# 167877                    actin-mediated cell contraction    0.0683
# 167878                      smooth muscle cell chemotaxis    0.0683
# 167879  establishment or maintenance of cell polarity ...    0.0085
# 167880                cranial skeletal system development    0.0262
#
#          model_name    protein_id  \
# 0               ESM  A4LBC3_CAEEL
# 1             ESM3c  Q9VI72_DROME
# 2          Prost-T5     MPRIP_RAT
# 3       Ankh3-Large   GGYF2_HUMAN
# 4       Ankh3-Large   GGYF2_HUMAN
# ...             ...           ...
# 167876      Prot-T5    PARV_CAEEL
# 167877     Prost-T5   PARVA_MOUSE
# 167878     Prost-T5   PARVA_MOUSE
# 167879          ESM   PARVB_HUMAN
# 167880        ESM3c   UBP48_DANRE
#
#                                             organism  \
# 0                            Caenorhabditis elegans.
# 1               Drosophila melanogaster (Fruit fly).
# 2                           Rattus norvegicus (Rat).
# 3                              Homo sapiens (Human).
# 4                              Homo sapiens (Human).
# ...                                              ...
# 167876                       Caenorhabditis elegans.
# 167877                         Mus musculus (Mouse).
# 167878                         Mus musculus (Mouse).
# 167879                         Homo sapiens (Human).
# 167880  Danio rerio (Zebrafish) (Brachydanio rerio).
#
#                                                 gene_name  ...  \
# 0       met-1 {ECO:0000313|EMBL:CCD65167.1, ECO:000031...  ...
# 1       Sas-4 {ECO:0000313|EMBL:AAF54053.2, ECO:000031...  ...
# 2                                                   Mprip  ...
# 3       GIGYF2 {ECO:0000303|PubMed:12771153, ECO:00003...  ...
# 4       GIGYF2 {ECO:0000303|PubMed:12771153, ECO:00003...  ...
# ...                                                   ...  ...
# 167876              pat-6 {ECO:0000312|WormBase:T21D12.4}  ...
# 167877                                              Parva  ...
# 167878                                              Parva  ...
# 167879                                              PARVB  ...
# 167880                                              usp48  ...
#
#         collapsed_support  n_collapsed_terms  collapsed_terms  identity  \
# 0                       0                  0              NaN   17.0657
# 1                       0                  0              NaN   17.9765
# 2                       0                  0              NaN   18.9787
# 3                       0                  0              NaN   20.2834
# 4                       0                  0              NaN   20.2834
# ...                   ...                ...              ...       ...
# 167876                  0                  0              NaN   34.1014
# 167877                  0                  0              NaN   37.4429
# 167878                  0                  0              NaN   37.4429
# 167879                  0                  0              NaN   34.4749
# 167880                  0                  0              NaN   14.2586
#
#        similarity  alignment_score  gaps_percentage  alignment_length  \
# 0         28.4223             -198          37.3849              1629
# 1         33.8753               29          22.9449              1107
# 2         34.3830               82          22.2979              1175
# 3         36.6145              266          24.1611              1341
# 4         36.6145              266          24.1611              1341
# ...           ...              ...              ...               ...
# 167876    50.6912              531          14.2857               434
# 167877    53.4247              645          16.6667               438
# 167878    53.4247              645          16.6667               438
# 167879    51.1416              597          18.4932               438
# 167880    22.4335             -401          59.5057              1052
#
#         length_query  length_reference
# 0               1059              1590
# 1               1059               901
# 2               1059              1029
# 3               1059              1299
# 4               1059              1299
# ...              ...               ...
# 167876           431               375
# 167877           431               372
# 167878           431               372
# 167879           431               364
# 167880           431              1047
#
# [167881 rows x 22 columns]

# %%
# Add a column before first column of fantasia_results with the column Gene_ID from proteome_info matching on 'accession' in fantasia_results and 'Longest_Transcript' in proteome_info
fantasia_results.insert(0, 'Gene_ID', fantasia_results['accession'].map(proteome_info.set_index('Longest_Transcript')['Gene_ID']))
fantasia_results
# Out:
#        Gene_ID           accession       go_id category evidence_code  \
# 0          g_8        anno1.g10.t1  GO:0000122        P           IGI
# 1          g_8        anno1.g10.t1  GO:0000242        C           IDA
# 2          g_8        anno1.g10.t1  GO:0001725        C           IDA
# 3          g_8        anno1.g10.t1  GO:0005768        C           IDA
# 4          g_8        anno1.g10.t1  GO:0005783        C           IDA
# ...        ...                 ...         ...      ...           ...
# 167876  g_4909  anno2.MSTRG.9998.2  GO:0060298        P           IMP
# 167877  g_4909  anno2.MSTRG.9998.2  GO:0070252        P           IMP
# 167878  g_4909  anno2.MSTRG.9998.2  GO:0071670        P           IMP
# 167879  g_4909  anno2.MSTRG.9998.2  GO:0071963        P           IMP
# 167880  g_4909  anno2.MSTRG.9998.2  GO:1904888        P           IMP
#
#                                            go_description  distance  \
# 0       negative regulation of transcription by RNA po...    0.0119
# 1                                 pericentriolar material    0.0410
# 2                                            stress fiber    0.0300
# 3                                                endosome    0.0425
# 4                                   endoplasmic reticulum    0.0425
# ...                                                   ...       ...
# 167876      positive regulation of sarcomere organization    0.1139
# 167877                    actin-mediated cell contraction    0.0683
# 167878                      smooth muscle cell chemotaxis    0.0683
# 167879  establishment or maintenance of cell polarity ...    0.0085
# 167880                cranial skeletal system development    0.0262
#
#          model_name    protein_id  \
# 0               ESM  A4LBC3_CAEEL
# 1             ESM3c  Q9VI72_DROME
# 2          Prost-T5     MPRIP_RAT
# 3       Ankh3-Large   GGYF2_HUMAN
# 4       Ankh3-Large   GGYF2_HUMAN
# ...             ...           ...
# 167876      Prot-T5    PARV_CAEEL
# 167877     Prost-T5   PARVA_MOUSE
# 167878     Prost-T5   PARVA_MOUSE
# 167879          ESM   PARVB_HUMAN
# 167880        ESM3c   UBP48_DANRE
#
#                                             organism  ... collapsed_support  \
# 0                            Caenorhabditis elegans.  ...                 0
# 1               Drosophila melanogaster (Fruit fly).  ...                 0
# 2                           Rattus norvegicus (Rat).  ...                 0
# 3                              Homo sapiens (Human).  ...                 0
# 4                              Homo sapiens (Human).  ...                 0
# ...                                              ...  ...               ...
# 167876                       Caenorhabditis elegans.  ...                 0
# 167877                         Mus musculus (Mouse).  ...                 0
# 167878                         Mus musculus (Mouse).  ...                 0
# 167879                         Homo sapiens (Human).  ...                 0
# 167880  Danio rerio (Zebrafish) (Brachydanio rerio).  ...                 0
#
#         n_collapsed_terms  collapsed_terms  identity  similarity  \
# 0                       0              NaN   17.0657     28.4223
# 1                       0              NaN   17.9765     33.8753
# 2                       0              NaN   18.9787     34.3830
# 3                       0              NaN   20.2834     36.6145
# 4                       0              NaN   20.2834     36.6145
# ...                   ...              ...       ...         ...
# 167876                  0              NaN   34.1014     50.6912
# 167877                  0              NaN   37.4429     53.4247
# 167878                  0              NaN   37.4429     53.4247
# 167879                  0              NaN   34.4749     51.1416
# 167880                  0              NaN   14.2586     22.4335
#
#        alignment_score  gaps_percentage  alignment_length  length_query  \
# 0                 -198          37.3849              1629          1059
# 1                   29          22.9449              1107          1059
# 2                   82          22.2979              1175          1059
# 3                  266          24.1611              1341          1059
# 4                  266          24.1611              1341          1059
# ...                ...              ...               ...           ...
# 167876             531          14.2857               434           431
# 167877             645          16.6667               438           431
# 167878             645          16.6667               438           431
# 167879             597          18.4932               438           431
# 167880            -401          59.5057              1052           431
#
#         length_reference
# 0                   1590
# 1                    901
# 2                   1029
# 3                   1299
# 4                   1299
# ...                  ...
# 167876               375
# 167877               372
# 167878               372
# 167879               364
# 167880              1047
#
# [167881 rows x 23 columns]

# %%
from goatools.obo_parser import GODag

# Cargar el archivo de ontología GO
go_obo_path = "/Users/ingridmipe/Documents/UM/Browne_Lab/data/go-basic.obo"  # Asegúrate de descargar este archivo y proporcionar la ruta correcta
go_dag = GODag(go_obo_path)

# Función para obtener la profundidad de un término GO
def get_go_depth(go_id):
    go_term = go_dag.get(go_id)
    return go_term.depth if go_term else None

# Calcular la profundidad para cada término GO en la columna 'go_id'
fantasia_results['GOterm_depth'] = fantasia_results['go_id'].apply(get_go_depth)

# Colocar la nueva columna 'GOterm_depth' después de 'go_id'
go_id_index = fantasia_results.columns.get_loc('go_id')
cols = fantasia_results.columns.tolist()
cols.insert(go_id_index + 1, cols.pop(cols.index('GOterm_depth')))
fantasia_results = fantasia_results[cols]

fantasia_results
# Out:
# /Users/ingridmipe/Documents/UM/Browne_Lab/data/go-basic.obo: fmt(1.2) rel(2025-07-22) 43,230 Terms
#        Gene_ID           accession       go_id  GOterm_depth category  \
# 0          g_8        anno1.g10.t1  GO:0000122          11.0        P
# 1          g_8        anno1.g10.t1  GO:0000242           2.0        C
# 2          g_8        anno1.g10.t1  GO:0001725           4.0        C
# 3          g_8        anno1.g10.t1  GO:0005768           7.0        C
# 4          g_8        anno1.g10.t1  GO:0005783           5.0        C
# ...        ...                 ...         ...           ...      ...
# 167876  g_4909  anno2.MSTRG.9998.2  GO:0060298          10.0        P
# 167877  g_4909  anno2.MSTRG.9998.2  GO:0070252           4.0        P
# 167878  g_4909  anno2.MSTRG.9998.2  GO:0071670           6.0        P
# 167879  g_4909  anno2.MSTRG.9998.2  GO:0071963           7.0        P
# 167880  g_4909  anno2.MSTRG.9998.2  GO:1904888           3.0        P
#
#        evidence_code                                     go_description  \
# 0                IGI  negative regulation of transcription by RNA po...
# 1                IDA                            pericentriolar material
# 2                IDA                                       stress fiber
# 3                IDA                                           endosome
# 4                IDA                              endoplasmic reticulum
# ...              ...                                                ...
# 167876           IMP      positive regulation of sarcomere organization
# 167877           IMP                    actin-mediated cell contraction
# 167878           IMP                      smooth muscle cell chemotaxis
# 167879           IMP  establishment or maintenance of cell polarity ...
# 167880           IMP                cranial skeletal system development
#
#         distance   model_name    protein_id  ... collapsed_support  \
# 0         0.0119          ESM  A4LBC3_CAEEL  ...                 0
# 1         0.0410        ESM3c  Q9VI72_DROME  ...                 0
# 2         0.0300     Prost-T5     MPRIP_RAT  ...                 0
# 3         0.0425  Ankh3-Large   GGYF2_HUMAN  ...                 0
# 4         0.0425  Ankh3-Large   GGYF2_HUMAN  ...                 0
# ...          ...          ...           ...  ...               ...
# 167876    0.1139      Prot-T5    PARV_CAEEL  ...                 0
# 167877    0.0683     Prost-T5   PARVA_MOUSE  ...                 0
# 167878    0.0683     Prost-T5   PARVA_MOUSE  ...                 0
# 167879    0.0085          ESM   PARVB_HUMAN  ...                 0
# 167880    0.0262        ESM3c   UBP48_DANRE  ...                 0
#
#        n_collapsed_terms  collapsed_terms  identity  similarity  \
# 0                      0              NaN   17.0657     28.4223
# 1                      0              NaN   17.9765     33.8753
# 2                      0              NaN   18.9787     34.3830
# 3                      0              NaN   20.2834     36.6145
# 4                      0              NaN   20.2834     36.6145
# ...                  ...              ...       ...         ...
# 167876                 0              NaN   34.1014     50.6912
# 167877                 0              NaN   37.4429     53.4247
# 167878                 0              NaN   37.4429     53.4247
# 167879                 0              NaN   34.4749     51.1416
# 167880                 0              NaN   14.2586     22.4335
#
#         alignment_score gaps_percentage  alignment_length  length_query  \
# 0                  -198         37.3849              1629          1059
# 1                    29         22.9449              1107          1059
# 2                    82         22.2979              1175          1059
# 3                   266         24.1611              1341          1059
# 4                   266         24.1611              1341          1059
# ...                 ...             ...               ...           ...
# 167876              531         14.2857               434           431
# 167877              645         16.6667               438           431
# 167878              645         16.6667               438           431
# 167879              597         18.4932               438           431
# 167880             -401         59.5057              1052           431
#
#         length_reference
# 0                   1590
# 1                    901
# 2                   1029
# 3                   1299
# 4                   1299
# ...                  ...
# 167876               375
# 167877               372
# 167878               372
# 167879               364
# 167880              1047
#
# [167881 rows x 24 columns]

# %%
# Save the updated fantasia_results to a new CSV file
output_path = '/Users/ingridmipe/Documents/UM/Browne_Lab/results/fantasia/experiments/AllCells_20251030164736_MarkerGenes/results_AllCells-MarkerGenes_GeneID-GOdepth.csv'
fantasia_results.to_csv(output_path, index=False)
